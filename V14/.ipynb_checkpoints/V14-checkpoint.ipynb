# %%
from uncertainties import ufloat
from uncertainties import unumpy as unp
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
Länge_Fehler = 1# in mm
Länge = [(980,67, 42.5),(960,46,22),(950,35.5,12.5)]   # (oben, oben_kugel, unten_kugel) in mm

Ls_oben = [ufloat(x[0],Länge_Fehler) - ufloat(x[1],Länge_Fehler) for x in Länge] # Länge bis oben an die Kugel in mm
Ls_unten = [ufloat(x[0],Länge_Fehler) - ufloat(x[2],Länge_Fehler) for x in Länge] # Länge bis oben an die Kugel in mm


Ls_oben
# Out:
# [913.0+/-1.4142135623730951,
#  914.0+/-1.4142135623730951,
#  914.5+/-1.4142135623730951]

# %%
def Fehler_des_Mittelwerts(array, n = 3):
    return np.std(array,ddof=1) / np.sqrt(n)

def nom(array):
    return [x.nominal_value for x in array]

Fehler_des_Mittelwerts(nom(Ls_unten))

Fehler_L_oben = np.sqrt(Fehler_des_Mittelwerts(nom(Ls_oben)) ** 2 + np.sqrt(Länge_Fehler + Länge_Fehler)**2)
Fehler_L_oben
L_oben = ufloat(np.average(nom(Ls_oben)),Fehler_L_oben)


L_unten = ufloat(np.average(nom(Ls_unten)),np.sqrt(Fehler_des_Mittelwerts(nom(Ls_unten)) ** 2 + np.sqrt(Länge_Fehler + Länge_Fehler)**2))


L = ((L_oben + L_unten) / 2) 
print(L)
# Out:
# 925.8+/-1.0

# %%
# Bestimmen von detla t
Fehler_Zeitmessung = 0.2
Ts = [38.56,38.7,38.62,38.62,38.61]

T = (ufloat(np.average(Ts),Fehler_des_Mittelwerts(Ts, n=5)) + ufloat(0, Fehler_Zeitmessung)) / 20
           
print(T)
# Out:
# 1.931+/-0.010

# %%
delta_t = T.std_dev * 20 # delta kleines t
n = 2 * delta_t / T.nominal_value * L.nominal_value / (0.3 * L.std_dev)
print(n)
# Out:
# 626.0458011140737

# %%
Durchmesser_Kugel = ufloat(24.0,0.05) # in mm

Höhe_Amplitudenmessung = ufloat(92,1) # mm
Unterkante_Kugel = ufloat(13,1) # mm 
Aufhängung = ufloat(950,1)

# %%
# Lange Messung
Reaktionszeit= 0.2
T_ges = ufloat(23 * 60 + 09.72,Reaktionszeit)
N = 1440 / 2

Ablesegenauigkeit = 1
Amplitudenmessung = [(0,18.2,0),
             (62,17.2,60.3),
             (110,16.3,45.5),
             (162,15.4,50.91),
             (212,14.9,48.35),
             (258,14.4,43.73),
             (306,13.8,46.54),
             (362,13.3,0),
             (450,12.4,139.23),
             (500,12.0,48.33),
             (546,11.6,44.13),
             (612,11.1,63.75),
             (670,10.7,55.73),
             (702,10.5,30.90),
             (760,10.1,55.92),
             (806,9.8,44.82),
             (860,9.5,51.99),
             (910,9.2,47.99),
             (970,8.9,57.98),
             (1002,8.8,30.88),
             (1050,8.6,46.13),
             (1100,8.3,48.11),
             (1148,8.1,46.48),
             (1202,7.9,52.00),
             (1250,7.7,0),
             (1298,7.5,93.14),
             (1348,7.3,48.11),
             (1400,7.1,50.39)          
            ] # (Anzahl Nulldurchgänge,Auslenknug, Delta Zeit)

print(T_ges / N)

print(len(Amplitudenmessung))
# Out:
# 1.93017+/-0.00028
# 28

# %%
N_Nulldurchgänge,Amplitude, Delta_T = zip(*Amplitudenmessung)
Delta_T = np.array(Delta_T)

Delta_Nulldurchgänge = [0]+ [(N_Nulldurchgänge[x+1] - N_Nulldurchgänge[x]) / 2 for x in range(len(Amplitudenmessung) - 1)]
print("\n".join([str(x) for x in list(zip(Delta_T / T.nominal_value,Delta_Nulldurchgänge))]))
N_Perioden = np.array(N_Nulldurchgänge) / 2
plt.plot(N_Nulldurchgänge, Amplitude)
# Out:
# (np.float64(0.0), 0)
# (np.float64(31.22572627000155), 31.0)
# (np.float64(23.561700585158718), 24.0)
# (np.float64(26.363212676712752), 26.0)
# (np.float64(25.037543369064263), 25.0)
# (np.float64(22.645124540417378), 23.0)
# (np.float64(24.100253741390915), 24.0)
# (np.float64(0.0), 28.0)
# (np.float64(72.09880379058566), 44.0)
# (np.float64(25.027186577598258), 25.0)
# (np.float64(22.852260369737458), 23.0)
# (np.float64(33.01227279788721), 33.0)
# (np.float64(28.859199420019674), 29.0)
# (np.float64(16.00124281497592), 16.0)
# (np.float64(28.957588938946714), 29.0)
# (np.float64(23.209569675314587), 23.0)
# (np.float64(26.92247941587696), 27.0)
# (np.float64(24.851121122676197), 25.0)
# (np.float64(30.024338459945106), 30.0)
# (np.float64(15.990886023509916), 16.0)
# (np.float64(23.887939516337838), 24.0)
# (np.float64(24.913261871472216), 25.0)
# (np.float64(24.069183366992903), 24.0)
# (np.float64(26.92765781160996), 27.0)
# (np.float64(0.0), 24.0)
# (np.float64(48.23157785717984), 24.0)
# (np.float64(24.913261871472216), 25.0)
# (np.float64(26.093936098596654), 26.0)

# %%
def Exponential_Function(t, a,delta):
    return a * np.e ** (delta * t)

(a_fit,delta_fit), cov = scipy.optimize.curve_fit(Exponential_Function, N_Perioden, Amplitude, sigma=[0.1] * len(Amplitude), absolute_sigma=True,bounds=([10,-0.1],[40,0.1]))
print(a_fit, delta_fit)
error = np.sqrt(np.diag(cov))
d_a_fit, d_delta_fit = error

print(error)
# Out:
# 17.376289062951283 -0.001370852267847657
# [4.56002119e-02 8.43971785e-06]

# %%
plt.errorbar(N_Perioden,Amplitude,[0.1] * len(Amplitude), fmt="r.")
plt.plot(N_Perioden, Exponential_Function(N_Perioden, a_fit,delta_fit))
plt.plot(N_Perioden, Exponential_Function(N_Perioden, a_fit+d_a_fit,delta_fit))

# %%
Amplitude_log = unp.log(unp.uarray(Amplitude,[0.1]*len(Amplitude)))
Amplitude_log

def linear(x,m,b):
    return m * x + b
    
(m_fit,b_fit), cov = scipy.optimize.curve_fit(linear, N_Perioden, unp.nominal_values(Amplitude_log), sigma=unp.std_devs(Amplitude_log), absolute_sigma=True)

error = np.sqrt(np.diag(cov))
d_m_fit, d_b_fit = error
plt.errorbar(N_Perioden, unp.nominal_values(Amplitude_log), unp.std_devs(Amplitude_log),fmt="r.")
plt.plot(N_Perioden, linear(N_Perioden,m_fit,b_fit))
plt.plot(N_Perioden, linear(N_Perioden,m_fit + d_m_fit,b_fit))

delta = ufloat(m_fit, d_m_fit) * T
print(delta)
# Out:
# -0.002645+/-0.000021
