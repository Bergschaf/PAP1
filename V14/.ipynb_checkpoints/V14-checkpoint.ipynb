# %%
from uncertainties import ufloat
from uncertainties import unumpy as unp
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
Länge_Fehler = 1# in mm
Länge = [(980,67, 42.5),(960,46,22),(950,35.5,12.5)]   # (oben, oben_kugel, unten_kugel) in mm

Ls_oben = [ufloat(x[0],Länge_Fehler) - ufloat(x[1],Länge_Fehler) for x in Länge] # Länge bis oben an die Kugel in mm
Ls_unten = [ufloat(x[0],Länge_Fehler) - ufloat(x[2],Länge_Fehler) for x in Länge] # Länge bis oben an die Kugel in mm


Ls_oben
# Out:
# /usr/lib/python3.14/site-packages/uncertainties/core.py:526: FutureWarning: AffineScalarFunc.error_components() is currently an instance method. This method is deprecated. In a future release it will be replaced with an instance property by the same name. It will be accessed by AffineScalarFunc.error_components (with no parentheses).
#   return float(sqrt(sum(delta**2 for delta in self.error_components().values())))
# /usr/lib/python3.14/site-packages/uncertainties/core.py:491: FutureWarning: AffineScalarFunc.derivatives() is deprecated. It will be removed in a future release.
#   for variable, derivative in self.derivatives.items():
# [913.0+/-1.4142135623730951,
#  914.0+/-1.4142135623730951,
#  914.5+/-1.4142135623730951]

# %%
def Fehler_des_Mittelwerts(array, n = 3):
    return np.std(array,ddof=1) / np.sqrt(n)

def nom(array):
    return [x.nominal_value for x in array]

Fehler_des_Mittelwerts(nom(Ls_unten))

Fehler_L_oben = np.sqrt(Fehler_des_Mittelwerts(nom(Ls_oben)) ** 2 + np.sqrt(Länge_Fehler + Länge_Fehler)**2)
Fehler_L_oben
L_oben = ufloat(np.average(nom(Ls_oben)),Fehler_L_oben)


L_unten = ufloat(np.average(nom(Ls_unten)),np.sqrt(Fehler_des_Mittelwerts(nom(Ls_unten)) ** 2 + np.sqrt(Länge_Fehler + Länge_Fehler)**2))


L = ((L_oben + L_unten) / 2) / 1000
print(L)
# Out:
# 0.9257+/-0.0010

# %%
# Bestimmen von detla t
Fehler_Zeitmessung = 0.2
Ts = [38.56,38.7,38.62,38.62,38.61]

T = (ufloat(np.average(Ts),Fehler_des_Mittelwerts(Ts, n=5)) + ufloat(0, Fehler_Zeitmessung)) / 20
           
print(T)
# Out:
# 1.931+/-0.010

# %%
delta_t = T.std_dev * 20 # delta kleines t
n = 2 * delta_t / T.nominal_value * L.nominal_value / (0.3 * L.std_dev)
print(n)
# Out:
# 626.0458011140737

# %%
Durchmesser_Kugel = ufloat(24.0,0.05) # in mm
Durchmesser_Kugel /= 1000 # in m

# %%
# Lange Messung
Reaktionszeit= 0.2
T_ges = ufloat(23 * 60 + 09.72,Reaktionszeit)
N = 1440 / 2

Ablesegenauigkeit = 1
Amplitudenmessung = [(0,18.2,0),
             (62,17.2,60.3),
             (110,16.3,45.5),
             (162,15.4,50.91),
             (212,14.9,48.35),
             (258,14.4,43.73),
             (306,13.8,46.54),
             (362,13.3,0),
             (450,12.4,139.23),
             (500,12.0,48.33),
             (546,11.6,44.13),
             (612,11.1,63.75),
             (670,10.7,55.73),
             (702,10.5,30.90),
             (760,10.1,55.92),
             (806,9.8,44.82),
             (860,9.5,51.99),
             (910,9.2,47.99),
             (970,8.9,57.98),
             (1002,8.8,30.88),
             (1050,8.6,46.13),
             (1100,8.3,48.11),
             (1148,8.1,46.48),
             (1202,7.9,52.00),
             (1250,7.7,0),
             (1298,7.5,93.14),
             (1348,7.3,48.11),
             (1400,7.1,50.39)          
            ] # (Anzahl Nulldurchgänge,Auslenknug, Delta Zeit)

print(T_ges / N)

print(len(Amplitudenmessung))
# Out:
# 1.93017+/-0.00028
# 28

# %%
N_Nulldurchgänge,Amplitude, Delta_T = zip(*Amplitudenmessung)
Amplitude = np.array(Amplitude) / 100
Delta_T = np.array(Delta_T)

Delta_Nulldurchgänge = [0]+ [(N_Nulldurchgänge[x+1] - N_Nulldurchgänge[x]) / 2 for x in range(len(Amplitudenmessung) - 1)]
print("\n".join([str(x) for x in list(zip(Delta_T / T.nominal_value,Delta_Nulldurchgänge))]))
N_Perioden = np.array(N_Nulldurchgänge) / 2
plt.plot(N_Nulldurchgänge, Amplitude)
# Out:
# (np.float64(0.0), 0)
# (np.float64(31.240825490026765), 31.0)
# (np.float64(23.573093860633794), 24.0)
# (np.float64(26.3759606251619), 26.0)
# (np.float64(25.0496502892669), 25.0)
# (np.float64(22.65607460495639), 23.0)
# (np.float64(24.11190743459114), 24.0)
# (np.float64(0.0), 28.0)
# (np.float64(72.13366721353941), 44.0)
# (np.float64(25.03928848976772), 25.0)
# (np.float64(22.86331059493999), 23.0)
# (np.float64(33.02823590363526), 33.0)
# (np.float64(28.873154304464205), 29.0)
# (np.float64(16.00898022623262), 16.0)
# (np.float64(28.971591399706416), 29.0)
# (np.float64(23.220792677661684), 23.0)
# (np.float64(26.935497798117606), 27.0)
# (np.float64(24.863137898281668), 25.0)
# (np.float64(30.03885674812192), 30.0)
# (np.float64(15.99861842673344), 16.0)
# (np.float64(23.899490544857958), 24.0)
# (np.float64(24.925308695276744), 25.0)
# (np.float64(24.080822036093597), 24.0)
# (np.float64(26.940678697867195), 27.0)
# (np.float64(0.0), 24.0)
# (np.float64(48.254900267679815), 24.0)
# (np.float64(24.925308695276744), 25.0)
# (np.float64(26.10655383818323), 26.0)

# %%
def Exponential_Function(t, a,delta):
    return a * np.e ** (delta * t)

(a_fit,delta_fit), cov = scipy.optimize.curve_fit(Exponential_Function, N_Perioden, Amplitude, sigma=[0.001] * len(Amplitude), absolute_sigma=True,bounds=([0,-0.1],[1,0.1]))
print(a_fit, delta_fit)
error = np.sqrt(np.diag(cov))
d_a_fit, d_delta_fit = error

print(error)
# Out:
# 0.1737628956835273 -0.0013708523875583186
# [4.56002126e-04 8.43971797e-06]

# %%
plt.errorbar(N_Perioden,Amplitude,[0.001] * len(Amplitude), fmt="r.")
plt.plot(N_Perioden, Exponential_Function(N_Perioden, a_fit,delta_fit))
plt.plot(N_Perioden, Exponential_Function(N_Perioden, a_fit+d_a_fit,delta_fit))

# %%
Amplitude_log = unp.log(unp.uarray(Amplitude,[0.001]*len(Amplitude)))
Amplitude_log

def linear(x,m,b):
    return m * x + b
    
(m_fit,b_fit), cov = scipy.optimize.curve_fit(linear, N_Perioden, unp.nominal_values(Amplitude_log), sigma=unp.std_devs(Amplitude_log), absolute_sigma=True)

error = np.sqrt(np.diag(cov))
d_m_fit, d_b_fit = error
plt.errorbar(N_Perioden, unp.nominal_values(Amplitude_log), unp.std_devs(Amplitude_log),fmt="r.")
plt.plot(N_Perioden, linear(N_Perioden,m_fit,b_fit))
plt.plot(N_Perioden, linear(N_Perioden,m_fit + d_m_fit,b_fit))

delta = -ufloat(m_fit, d_m_fit) * T
print(delta)
# Out:
# 0.002644+/-0.000016

# %% [markdown]
# # Erste Rechnung für g

# %%
Radius_Kugel = Durchmesser_Kugel / 2
T = T_ges / N
rho_F = 7.83 * 1000 # kg/m^3
rho_L =  1.2041 # kg / m^3
r_Faden = 0.1 * 10**(-3) # m
V_Kugel = 4/3 * np.pi * Radius_Kugel ** 3
m_Kugel = rho_F * V_Kugel
m_Faden = L * rho_F * np.pi * r_Faden ** 2

print(m_Kugel)
print(m_Faden)
print(T)
print(L)
# Out:
# 0.05668+/-0.00035
# 0.00022772+/-0.00000025
# 1.93017+/-0.00028
# 0.9257+/-0.0010

# %%
Korrektur_r_l = 2/5 * Radius_Kugel**2 / L**2 
Korrektur_dichte = rho_L/rho_F 
Korrektur_masse = 1/6 * m_Faden /m_Kugel


g_1 = (4 * np.pi**2 * L)/T**2 *(1+ Korrektur_r_l + Korrektur_dichte - Korrektur_masse)
print(g_1)

print(Korrektur_r_l)
print(Korrektur_dichte)
print(Korrektur_masse)
# Out:
# 9.805+/-0.011
# (6.721+/-0.032)e-05
# 0.00015378033205619413
# 0.000670+/-0.000004

# %% [markdown]
# # Zweite Rechnung für g

# %%
omega_0 = 2 * np.pi / T

# phi_0 berechnen
Höhe_Amplitudenmessung = ufloat(92,1) / 1000 # m
Unterkante_Kugel = ufloat(13,1) / 1000 # m 
Aufhängung = ufloat(950,1) / 1000
Auslenkung_max = np.average(Amplitude) # ufloat(0.182,0.001)
Messhöhe = Aufhängung - Höhe_Amplitudenmessung 
tan_phi = Auslenkung_max / Messhöhe
phi_0 = unp.arctan(tan_phi) 
print(phi_0 / (2 * np.pi) * 360)

Korrektur_delta = delta**2 / omega_0**2
Korrektur_phi_0 = phi_0**2 / 8
print(Korrektur_delta, Korrektur_phi_0)
# Out:
# 7.367+/-0.012
# (6.60+/-0.08)e-07 0.002066+/-0.000007

# %%
g_2 = (4 * np.pi**2 * L)/T**2 *(1+ Korrektur_r_l + Korrektur_dichte - Korrektur_masse + Korrektur_delta + Korrektur_phi_0)
print(g_2)
# Out:
# 9.826+/-0.011
