# %%
from uncertainties import ufloat
from uncertainties import unumpy as unp

# %% [markdown]
# # Aufgabe 1

# %%
x_Linse = ufloat(350,1) #mm
x_gegenstand = ufloat(505,1) #mm
x_Schirm = ufloat(76,1) #mm

b = x_Linse - x_Schirm
g = x_gegenstand- x_Linse
f = 1/(1/b +1/g)

print(b, g, f)
# Out:
# 274.0+/-1.4 155.0+/-1.4 99.0+/-0.5
# /usr/lib/python3.14/site-packages/uncertainties/core.py:526: FutureWarning: AffineScalarFunc.error_components() is currently an instance method. This method is deprecated. In a future release it will be replaced with an instance property by the same name. It will be accessed by AffineScalarFunc.error_components (with no parentheses).
#   return float(sqrt(sum(delta**2 for delta in self.error_components().values())))
# /usr/lib/python3.14/site-packages/uncertainties/core.py:491: FutureWarning: AffineScalarFunc.derivatives() is deprecated. It will be removed in a future release.
#   for variable, derivative in self.derivatives.items():

# %%
x_Linsen =      [340,390,415,440,490,465,575]
x_Gegenstände = [640,640,640,640,640,640,700]
x_Schirme =     [190.5,225,236.5,241,189,234,40]
x_Linsen = unp.uarray(x_Linsen,[1]*len(x_Linsen))
x_Gegenstände = unp.uarray(x_Gegenstände,[1]*len(x_Gegenstände))
x_Schirme = unp.uarray(x_Schirme,[1]*len(x_Schirme))
b = x_Linsen - x_Schirme
g = x_Gegenstände - x_Linsen

print("b:",b)
print("g:",g)
print("\n".join(str(x) for x in zip(b,g)))
# Out:
# b: [149.5+/-1.4142135623730951 165.0+/-1.4142135623730951
#  178.5+/-1.4142135623730951 199.0+/-1.4142135623730951
#  301.0+/-1.4142135623730951 231.0+/-1.4142135623730951
#  535.0+/-1.4142135623730951]
# g: [300.0+/-1.4142135623730951 250.0+/-1.4142135623730951
#  225.0+/-1.4142135623730951 200.0+/-1.4142135623730951
#  150.0+/-1.4142135623730951 175.0+/-1.4142135623730951
#  125.0+/-1.4142135623730951]
# (149.5+/-1.4142135623730951, 300.0+/-1.4142135623730951)
# (165.0+/-1.4142135623730951, 250.0+/-1.4142135623730951)
# (178.5+/-1.4142135623730951, 225.0+/-1.4142135623730951)
# (199.0+/-1.4142135623730951, 200.0+/-1.4142135623730951)
# (301.0+/-1.4142135623730951, 150.0+/-1.4142135623730951)
# (231.0+/-1.4142135623730951, 175.0+/-1.4142135623730951)
# (535.0+/-1.4142135623730951, 125.0+/-1.4142135623730951)

# %% [markdown]
# # Aufgabe 2 (Bessel)

# %%
def mittel(x):
    return sum(x)/len(x)

# %%
#Schirm_2 = ufloat(10,1)
#Gegenstand_2 = ufloat(700,1)
#Linse_pos1 = unp.uarray([543.5,543.5,544],[1]*3)
#Linse_pos2  = unp.uarray([70.5,69.5,71],[1]*3)

#Linse_pos1_rot = unp.uarray([542,541.5,542.5],[1]*3)
#Linse_pos2_rot = unp.uarray([70.5,71.5,71],[1]*3)

#Linse_pos1_blau = unp.uarray([546,547,545.5],[1]*3)
#Linse_pos2_blau = unp.uarray([66.5,67,65.5],[1]*3)

#f_Bessel =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1 - Linse_pos2)**2)/(4 * abs(Schirm_2 - Gegenstand_2)) 
#f_Bessel_rot =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_rot - Linse_pos2_rot)**2)/(4 * abs(Schirm_2-Gegenstand_2)) 
#f_Bessel_blau =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_blau - Linse_pos2_blau)**2)/(4 * abs(Schirm_2-Gegenstand_2)) 


#print(f_Bessel)
#print(f_Bessel_rot)
#print(f_Bessel_blau)
#print(mittel(f_Bessel), mittel(f_Bessel_rot), mittel(f_Bessel_blau))

# %%
Schirm_2 = ufloat(898,1)
Gegenstand_2 = ufloat(200,1)
Linse_pos1 = unp.uarray([356.5,357.5,356.6],[1]*3)
Linse_pos2  = unp.uarray([742.5,743.5,743.5],[1]*3)

Linse_pos1_rot = unp.uarray([359,360,359],[1]*3)
Linse_pos2_rot = unp.uarray([740.5,740.5,741.5],[1]*3)

Linse_pos1_blau = unp.uarray([355,354,354.5],[1]*3)
Linse_pos2_blau = unp.uarray([745,744.5,746.5],[1]*3)

f_Bessel =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1 - Linse_pos2)**2)/(4 * abs(Schirm_2 - Gegenstand_2)) 
f_Bessel_rot =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_rot - Linse_pos2_rot)**2)/(4 * abs(Schirm_2-Gegenstand_2)) 
f_Bessel_blau =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_blau - Linse_pos2_blau)**2)/(4 * abs(Schirm_2-Gegenstand_2)) 


#print(f_Bessel)
#print(f_Bessel_rot)
#print(f_Bessel_blau)
print(mittel(f_Bessel), mittel(f_Bessel_rot), mittel(f_Bessel_blau))
# Out:
# 121.1+/-0.5 122.4+/-0.5 119.8+/-0.5
# /tmp/ipykernel_71988/3437706269.py:12: FutureWarning: AffineScalarFunc.__abs__() is deprecated. It will be removed in a future release.
#   f_Bessel =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1 - Linse_pos2)**2)/(4 * abs(Schirm_2 - Gegenstand_2))
# /tmp/ipykernel_71988/3437706269.py:13: FutureWarning: AffineScalarFunc.__abs__() is deprecated. It will be removed in a future release.
#   f_Bessel_rot =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_rot - Linse_pos2_rot)**2)/(4 * abs(Schirm_2-Gegenstand_2))
# /tmp/ipykernel_71988/3437706269.py:14: FutureWarning: AffineScalarFunc.__abs__() is deprecated. It will be removed in a future release.
#   f_Bessel_blau =((Schirm_2-Gegenstand_2)**2 - (Linse_pos1_blau - Linse_pos2_blau)**2)/(4 * abs(Schirm_2-Gegenstand_2))
