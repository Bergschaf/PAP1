# %%
import numpy as np

# %%
t2 = np.array([4.95,4.54,4.53,4.50,4.58,4.67,4.54,4.59,4.54,4.5])
t1 = np.array([4.96,5,4.95,4.94,4.89,5.04,4.89,5.07,4.95,5.01])
print(np.average(t2/3))
print(np.std(t2,ddof=1)/np.sqrt(10))
print(t2/3)
# Out:
# 1.5313333333333334
# 0.04258847000982517
# [1.65       1.51333333 1.51       1.5        1.52666667 1.55666667
#  1.51333333 1.53       1.51333333 1.5       ]
